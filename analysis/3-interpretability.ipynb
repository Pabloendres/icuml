# %% [markdown]
# # Interpretability layer
#
#
# In this notebook, interpretability layer for each strategy are made.
#
# This require high computational power. The entire notebook, including model fitting and feature selection, can be run in about 40-60 minutes using a 16-core CPU. Set `run = True` to run the notebook including intensive task. Otherwise, set `run = False` to use previously saved work and solely plot results.

# %%
run = False
import aidxmods as axm
import matplotlib.pyplot as plt

# %%
strata20xg = axm.load('strata20xg')
axm.setfig(figsize=(4, 8))
strata20xg.shap_summary('test', refresh=run)
axm.handlefig('3-strata20xg-shap-test')
strata20xg.save()

stratb20xg = axm.load('stratb20xg')
axm.setfig(figsize=(4, 8))
stratb20xg.shap_summary('test', refresh=run)
axm.handlefig('3-stratb20xg-shap-test')
stratb20xg.save()

stratc = axm.load('stratc')
axm.setfig(figsize=(4, 8))
stratc.shap_summary('test', refresh=run)
axm.handlefig('3-stratc-shap-test')
axm.setfig(figsize=(1, 8))
fig = stratc.shap_summary('test', color_bar=True)
axm.handlefig('3-stratc-shap-colorbar')
stratc.save()
